# %% [markdown]
# # Import the Required Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# # Load the Image Training and Validation Datasets

# %%
train_dataset_path = '/kaggle/input/riceleafs2/RiceLeafs2/train'
validation_dataset_path = '/kaggle/input/riceleafs2/RiceLeafs2/validation'

# %%
target_size = (50, 50)

train_datagen = ImageDataGenerator(
    rescale=1./255,  
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)


validation_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    train_dataset_path,
    target_size=target_size,  
    batch_size=16,  
    class_mode='categorical'  
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dataset_path,
    target_size=target_size, 
    batch_size=16, 
    class_mode='categorical' 
)
# Out:
# Found 80 images belonging to 4 classes.
# Found 56 images belonging to 4 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : BrownSpot
# 1 : Healthy
# 2 : Hispa
# 3 : LeafBlast

# %% [markdown]
# # Plotting Sample Training Images

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %% [markdown]
# # Training a CNN Model

# %%
input_shape = (50, 50, 3)
def create_model(input_shape):
    model = Sequential([
        Conv2D(64, kernel_size=(5, 5), activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(2, 2)),
        Conv2D(128, kernel_size=(5, 5), activation='relu'),
        MaxPooling2D(pool_size=(2, 2)),
        Flatten(),
        Dense(256, activation='relu'),
        Dense(4, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model(input_shape)

print(cnn_model.summary())
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_7 (Conv2D)               │ (None, 46, 46, 64)     │         4,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 19, 19, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 9, 9, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 10368)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │     2,654,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,865,284 (10.93 MB)
#  Trainable params: 2,865,284 (10.93 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

optimizer = Adam(learning_rate=0.0001)

cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=25, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/25
# W0000 00:00:1717216151.058283     148 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1717216152.927778     150 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 5/5 - 12s - 2s/step - accuracy: 0.2375 - loss: 1.4179 - val_accuracy: 0.2500 - val_loss: 1.4002 - learning_rate: 1.0000e-04
# Epoch 2/25
# 5/5 - 6s - 1s/step - accuracy: 0.2750 - loss: 1.3948 - val_accuracy: 0.2679 - val_loss: 1.4222 - learning_rate: 1.0000e-04
# Epoch 3/25
# 5/5 - 6s - 1s/step - accuracy: 0.3125 - loss: 1.3557 - val_accuracy: 0.2143 - val_loss: 1.3885 - learning_rate: 1.0000e-04
# Epoch 4/25
# 5/5 - 6s - 1s/step - accuracy: 0.3375 - loss: 1.3387 - val_accuracy: 0.2500 - val_loss: 1.3848 - learning_rate: 1.0000e-04
# Epoch 5/25
# 5/5 - 6s - 1s/step - accuracy: 0.3250 - loss: 1.3008 - val_accuracy: 0.1250 - val_loss: 1.3782 - learning_rate: 1.0000e-04
# Epoch 6/25
# 5/5 - 6s - 1s/step - accuracy: 0.6125 - loss: 1.2448 - val_accuracy: 0.1429 - val_loss: 1.3625 - learning_rate: 1.0000e-04
# Epoch 7/25
# 5/5 - 6s - 1s/step - accuracy: 0.5625 - loss: 1.2117 - val_accuracy: 0.1786 - val_loss: 1.3623 - learning_rate: 1.0000e-04
# Epoch 8/25
# 5/5 - 6s - 1s/step - accuracy: 0.6500 - loss: 1.1597 - val_accuracy: 0.2321 - val_loss: 1.3469 - learning_rate: 1.0000e-04
# Epoch 9/25
# 5/5 - 6s - 1s/step - accuracy: 0.6250 - loss: 1.0893 - val_accuracy: 0.1964 - val_loss: 1.3299 - learning_rate: 1.0000e-04
# Epoch 10/25
# 5/5 - 6s - 1s/step - accuracy: 0.6125 - loss: 1.0487 - val_accuracy: 0.1964 - val_loss: 1.3884 - learning_rate: 1.0000e-04
# Epoch 11/25
# 5/5 - 6s - 1s/step - accuracy: 0.7125 - loss: 0.9523 - val_accuracy: 0.1786 - val_loss: 1.3591 - learning_rate: 1.0000e-04
# Epoch 12/25
# 5/5 - 6s - 1s/step - accuracy: 0.6750 - loss: 0.9206 - val_accuracy: 0.1250 - val_loss: 1.4427 - learning_rate: 1.0000e-04
# Epoch 13/25
# 5/5 - 6s - 1s/step - accuracy: 0.7000 - loss: 0.8589 - val_accuracy: 0.1786 - val_loss: 1.5077 - learning_rate: 1.0000e-04
# Epoch 14/25
# 5/5 - 6s - 1s/step - accuracy: 0.7250 - loss: 0.8334 - val_accuracy: 0.1607 - val_loss: 1.4736 - learning_rate: 1.0000e-04
# Epoch 15/25
# 5/5 - 6s - 1s/step - accuracy: 0.7750 - loss: 0.7962 - val_accuracy: 0.1786 - val_loss: 1.4954 - learning_rate: 3.1623e-05
# Epoch 16/25
# 5/5 - 6s - 1s/step - accuracy: 0.7375 - loss: 0.7453 - val_accuracy: 0.1071 - val_loss: 1.6280 - learning_rate: 3.1623e-05
# Epoch 17/25
# 5/5 - 6s - 1s/step - accuracy: 0.7625 - loss: 0.7359 - val_accuracy: 0.1786 - val_loss: 1.5634 - learning_rate: 3.1623e-05
# Epoch 18/25
# 5/5 - 6s - 1s/step - accuracy: 0.7500 - loss: 0.7418 - val_accuracy: 0.1786 - val_loss: 1.5344 - learning_rate: 3.1623e-05
# Epoch 19/25
# 5/5 - 6s - 1s/step - accuracy: 0.7375 - loss: 0.7249 - val_accuracy: 0.1786 - val_loss: 1.6353 - learning_rate: 3.1623e-05
# Epoch 20/25
# 5/5 - 6s - 1s/step - accuracy: 0.8000 - loss: 0.6941 - val_accuracy: 0.1786 - val_loss: 1.6013 - learning_rate: 1.0000e-05
# Epoch 21/25
# 5/5 - 7s - 1s/step - accuracy: 0.7625 - loss: 0.6942 - val_accuracy: 0.1786 - val_loss: 1.5688 - learning_rate: 1.0000e-05
# Epoch 22/25
# 5/5 - 6s - 1s/step - accuracy: 0.7750 - loss: 0.6785 - val_accuracy: 0.1786 - val_loss: 1.5719 - learning_rate: 1.0000e-05
# Epoch 23/25
# 5/5 - 6s - 1s/step - accuracy: 0.7500 - loss: 0.6875 - val_accuracy: 0.1786 - val_loss: 1.5884 - learning_rate: 1.0000e-05
# Epoch 24/25
# 5/5 - 6s - 1s/step - accuracy: 0.7500 - loss: 0.6821 - val_accuracy: 0.1786 - val_loss: 1.5875 - learning_rate: 1.0000e-05
# Epoch 25/25
# 5/5 - 6s - 1s/step - accuracy: 0.7625 - loss: 0.7016 - val_accuracy: 0.1786 - val_loss: 1.5906 - learning_rate: 3.1623e-06

# %% [markdown]
# # Plotting the Model Metrics

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

learning_rate = history.history['learning_rate']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

ax[2].set_title('Learning Rate vs. Epochs')
ax[2].plot(learning_rate, 'o-', label='Learning Rate')
ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing the Model on Test Set

# %%
test_dataset = '/kaggle/input/riceleafs2/RiceLeafs2/validation'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=16,
                                                 target_size = (50, 50),
                                                 class_mode='categorical')
# Out:
# Found 56 images belonging to 4 classes.

# %% [markdown]
# # Model Prediction on the Test Dataset

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# W0000 00:00:1717216729.387624     150 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=16)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 392ms/step - accuracy: 0.2777 - loss: 1.5427

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     1.5905736684799194
# Test Accuracy: 0.1785714328289032

# %% [markdown]
# # Plotting the Classification Metrics

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(cf_mtx.shape[0], cf_mtx.shape[1])

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#    BrownSpot       0.30      0.64      0.41        14
#      Healthy       0.00      0.00      0.00        14
#        Hispa       0.00      0.00      0.00        14
#    LeafBlast       0.08      0.07      0.08        14
#
#     accuracy                           0.18        56
#    macro avg       0.10      0.18      0.12        56
# weighted avg       0.10      0.18      0.12        56

# %% [markdown]
# # Wrong Predictions

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
